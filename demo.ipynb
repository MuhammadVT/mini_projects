# %% [markdown]
# # Removing Seasonal Noise

# %% [markdown]
# Here are a few attemps to remove seasonal noise from a small set of data

# %%
# load the packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# import some functions from custom codes
from read_data import read_data
from moving_avg import moving_average

# %%
# read data from a .m file into a DataFrame
df = read_data("./original.mat")
df.head()
# Out:
#      original       true
# 0   -9.984730  64.054990
# 1  407.817850  71.681451
# 2  687.763042  76.882458
# 3  566.139743  86.665747
# 4  116.433781  91.277430

# %%
# %matplotlib inline

# plot the data
df.plot(figsize=(12,8))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Remove noise by performaing running average with optimal window size and window types

# %%
optimal_window = True  # this will set the code to search for optimal window size and window type
#optimal_window = False
iter_num = 50
err_type = "root-mean-sqrt"
#err_type = "mean-absolute"

# Do the moving average with optimal values of window size and window type
dfn = moving_average(df, window=10, optimal_window=optimal_window, err_type=err_type)
dfn.plot(figsize=(12,8))
# Out:
# Best pair of window and win_type are:
# window = 19
# win_type is  hamming

# %% [markdown]
# # Remove noise by filtering out high frequency components
